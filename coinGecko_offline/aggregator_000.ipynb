# %%
import pandas as pd
import os

# Set the folder path
folder_path = 'daily_sorted_mcap_125_assets'  # Replace with your actual folder path

# Initialize an empty DataFrame to store the aggregated data
aggregated_data = pd.DataFrame({'rank': range(1, 126)})

# Loop through each CSV file in the folder
for file_name in sorted(os.listdir(folder_path)):
    if file_name.endswith('.csv'):
        # Read the CSV file
        file_path = os.path.join(folder_path, file_name)
        data = pd.read_csv(file_path)
        
        # Extract the 'ID' column
        ids = data['ID'].head(125)
        
        # Pad the column with NaN if it has fewer than 125 entries
        ids = ids.reindex(range(125), fill_value=None)
        
        # Add the extracted 'ID' column to the aggregated DataFrame
        column_name = file_name.split('.')[0]  # Use the file name (without extension) as the column name
        aggregated_data[column_name] = ids.values

# Transpose the DataFrame so columns become rows and rows become columns
rotated_data = aggregated_data.set_index('rank').transpose()

# Save the rotated data to a new CSV file
output_file = 'rotated_cryptocurrency_ids.csv'
rotated_data.to_csv(output_file, index_label='Date')

print(f"Rotated data saved to {output_file}")
# Out:
# C:\Users\!mm32205\AppData\Local\Temp\ipykernel_30464\3623429440.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   aggregated_data[column_name] = ids.values
# C:\Users\!mm32205\AppData\Local\Temp\ipykernel_30464\3623429440.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   aggregated_data[column_name] = ids.values
# ...
