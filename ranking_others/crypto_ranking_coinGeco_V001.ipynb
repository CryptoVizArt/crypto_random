# %%
import requests
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def get_top_100_at_date(date_str):
    """
    Get top 100 cryptocurrencies for a specific date
    date_str format: YYYY-MM-DD
    """
    url = "https://api.coingecko.com/api/v3/coins/markets"
    params = {
        'vs_currency': 'usd',
        'order': 'market_cap_desc',
        'per_page': 100,
        'page': 1,
        'sparkline': False,
        'date': date_str
    }
    
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise exception for bad status codes
        return response.json()
    except Exception as e:
        print(f"Error for {date_str}: {e}")
        return None

def get_coin_market_cap(coin_id, from_date, to_date):
    """
    Get market cap data for a single coin with better error handling
    """
    url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart/range"
    from_timestamp = int(datetime.strptime(from_date, '%Y-%m-%d').timestamp())
    to_timestamp = int(datetime.strptime(to_date, '%Y-%m-%d').timestamp())
    
    params = {
        'vs_currency': 'usd',
        'from': from_timestamp,
        'to': to_timestamp
    }
    
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        return data.get('market_caps', [])
    except Exception as e:
        print(f"Error getting market cap for {coin_id}: {e}")
        return []

def track_market_caps(historical_lists):
    """
    Enhanced market cap tracking with better error handling and progress tracking
    """
    today = datetime.now().strftime('%Y-%m-%d')
    all_market_caps = {}
    
    for date_label, assets in historical_lists.items():
        print(f"\nProcessing list: {date_label}")
        creation_date = date_label.split('_')[0]
        daily_totals = {}
        
        for i, (symbol, name, coin_id) in enumerate(assets, 1):
            if coin_id:
                print(f"Processing {symbol} ({i}/100)")
                market_caps = get_coin_market_cap(coin_id, creation_date, today)
                
                for timestamp_ms, market_cap in market_caps:
                    date = datetime.fromtimestamp(timestamp_ms/1000).strftime('%Y-%m-%d')
                    daily_totals[date] = daily_totals.get(date, 0) + market_cap
            
            time.sleep(1.2)  # Respect rate limits
        
        all_market_caps[date_label] = daily_totals
    
    return all_market_caps

def create_visualization(market_cap_df):
    """
    Create an interactive visualization using plotly
    """
    # Convert market cap to billions for better readability
    market_cap_df['total_market_cap_billions'] = market_cap_df['total_market_cap'] / 1e9
    
    # Create the figure
    fig = go.Figure()
    
    # Add a line for each historical list
    for date_label in market_cap_df['list_date_label'].unique():
        df_subset = market_cap_df[market_cap_df['list_date_label'] == date_label]
        fig.add_trace(go.Scatter(
            x=df_subset['tracking_date'],
            y=df_subset['total_market_cap_billions'],
            name=date_label,
            mode='lines',
            hovertemplate='Date: %{x}<br>Market Cap: $%{y:.2f}B<extra></extra>'
        ))
    
    # Update layout
    fig.update_layout(
        title='Historical Top 100 Lists - Market Cap Tracking',
        xaxis_title='Date',
        yaxis_title='Total Market Cap (Billions USD)',
        hovermode='x unified',
        legend_title='List Date',
        template='plotly_white',
        height=800
    )
    
    # Save the plot
    fig.write_html('market_cap_visualization.html')
    return fig

def main():
    # Define historical dates
    historical_dates = [
        "2018-01-01",
        "2020-01-01",
        "2022-01-01"
    ]
    
    # Get historical lists
    print("Creating historical lists...")
    historical_lists = {}
    for date in historical_dates:
        print(f"Fetching data for {date}")
        data = get_top_100_at_date(date)
        if data:
            assets = [(coin['symbol'].upper(), coin['name'], coin.get('id')) 
                     for coin in data if coin.get('id')]  # Only include coins with valid IDs
            date_label = f"{date}_t100"
            historical_lists[date_label] = assets
            time.sleep(1.2)
    
    # Track market caps with progress updates
    print("\nTracking market caps...")
    market_cap_data = track_market_caps(historical_lists)
    
    # Convert to DataFrame
    market_cap_records = []
    for date_label, daily_caps in market_cap_data.items():
        for date, market_cap in daily_caps.items():
            market_cap_records.append({
                'list_date_label': date_label,
                'tracking_date': date,
                'total_market_cap': market_cap
            })
    
    market_cap_df = pd.DataFrame(market_cap_records)
    
    # Save to CSV
    print("\nSaving results...")
    market_cap_df.to_csv('historical_lists_market_cap_tracking.csv', index=False)
    
    # Create visualization
    print("\nCreating visualization...")
    fig = create_visualization(market_cap_df)
    
    print("\nDone! Check 'historical_lists_market_cap_tracking.csv' and 'market_cap_visualization.html'")
    
    # Print some basic statistics
    print("\nBasic Statistics:")
    for date_label in market_cap_df['list_date_label'].unique():
        df_subset = market_cap_df[market_cap_df['list_date_label'] == date_label]
        print(f"\n{date_label}:")
        print(f"Average Market Cap: ${df_subset['total_market_cap'].mean()/1e9:.2f}B")
        print(f"Max Market Cap: ${df_subset['total_market_cap'].max()/1e9:.2f}B")
        print(f"Min Market Cap: ${df_subset['total_market_cap'].min()/1e9:.2f}B")

if __name__ == "__main__":
    main()
# Out:
# Creating historical lists...
# Fetching data for 2018-01-01
# Fetching data for 2020-01-01
# Fetching data for 2022-01-01
#
# Tracking market caps...
#
# Processing list: 2018-01-01_t100
# Processing BTC (1/100)
# Error getting market cap for bitcoin: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing ETH (2/100)
# Error getting market cap for ethereum: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/ethereum/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing USDT (3/100)
# Error getting market cap for tether: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tether/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing SOL (4/100)
# Error getting market cap for solana: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing BNB (5/100)
# Error getting market cap for binancecoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/binancecoin/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing DOGE (6/100)
# Error getting market cap for dogecoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/dogecoin/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing XRP (7/100)
# Error getting market cap for ripple: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ripple/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing USDC (8/100)
# Error getting market cap for usd-coin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/usd-coin/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing STETH (9/100)
# Error getting market cap for staked-ether: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/staked-ether/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing ADA (10/100)
# Error getting market cap for cardano: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing SHIB (11/100)
# Error getting market cap for shiba-inu: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/shiba-inu/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing TRX (12/100)
# Error getting market cap for tron: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tron/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing WSTETH (13/100)
# Error getting market cap for wrapped-steth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/wrapped-steth/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing AVAX (14/100)
# Error getting market cap for avalanche-2: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/avalanche-2/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing TON (15/100)
# Error getting market cap for the-open-network: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/the-open-network/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing WBTC (16/100)
# Error getting market cap for wrapped-bitcoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/wrapped-bitcoin/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing SUI (17/100)
# Error getting market cap for sui: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/sui/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing WETH (18/100)
# Error getting market cap for weth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/weth/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing PEPE (19/100)
# Error getting market cap for pepe: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/pepe/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing BCH (20/100)
# Error getting market cap for bitcoin-cash: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bitcoin-cash/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing LINK (21/100)
# Error getting market cap for chainlink: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/chainlink/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing DOT (22/100)
# Error getting market cap for polkadot: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/polkadot/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing LEO (23/100)
# Error getting market cap for leo-token: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/leo-token/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing NEAR (24/100)
# Error getting market cap for near: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/near/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing APT (25/100)
# Error getting market cap for aptos: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/aptos/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing WEETH (26/100)
# Error getting market cap for wrapped-eeth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/wrapped-eeth/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing LTC (27/100)
# Error getting market cap for litecoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/litecoin/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing UNI (28/100)
# Error getting market cap for uniswap: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/uniswap/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing USDS (29/100)
# Error getting market cap for usds: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/usds/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing CRO (30/100)
# Error getting market cap for crypto-com-chain: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/crypto-com-chain/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing ICP (31/100)
# Error getting market cap for internet-computer: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/internet-computer/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing TAO (32/100)
# Error getting market cap for bittensor: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bittensor/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing WIF (33/100)
# Error getting market cap for dogwifcoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/dogwifcoin/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing XLM (34/100)
# Error getting market cap for stellar: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/stellar/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing ETC (35/100)
# Error getting market cap for ethereum-classic: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum-classic/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing FET (36/100)
# Error getting market cap for fetch-ai: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fetch-ai/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing KAS (37/100)
# Error getting market cap for kaspa: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/kaspa/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing DAI (38/100)
# Error getting market cap for dai: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/dai/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing WBT (39/100)
# Error getting market cap for whitebit: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/whitebit/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing POL (40/100)
# Error getting market cap for polygon-ecosystem-token: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/polygon-ecosystem-token/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing USDE (41/100)
# Error getting market cap for ethena-usde: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethena-usde/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing STX (42/100)
# Error getting market cap for blockstack: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/blockstack/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing BONK (43/100)
# Error getting market cap for bonk: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bonk/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing RENDER (44/100)
# Error getting market cap for render-token: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/render-token/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing XMR (45/100)
# Error getting market cap for monero: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/monero/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing OKB (46/100)
# Error getting market cap for okb: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/okb/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing AAVE (47/100)
# Error getting market cap for aave: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/aave/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing ARB (48/100)
# Error getting market cap for arbitrum: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/arbitrum/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing FIL (49/100)
# Error getting market cap for filecoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/filecoin/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing MNT (50/100)
# Error getting market cap for mantle: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mantle/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing INJ (51/100)
# Error getting market cap for injective-protocol: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/injective-protocol/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing FLOKI (52/100)
# Error getting market cap for floki: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/floki/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing FDUSD (53/100)
# Error getting market cap for first-digital-usd: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/first-digital-usd/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing HBAR (54/100)
# Error getting market cap for hedera-hashgraph: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/hedera-hashgraph/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing VET (55/100)
# Error getting market cap for vechain: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/vechain/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing TIA (56/100)
# Error getting market cap for celestia: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/celestia/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing IMX (57/100)
# Error getting market cap for immutable-x: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/immutable-x/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing OP (58/100)
# Error getting market cap for optimism: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/optimism/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing FTM (59/100)
# Error getting market cap for fantom: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing ATOM (60/100)
# Error getting market cap for cosmos: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cosmos/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing BGB (61/100)
# Error getting market cap for bitget-token: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bitget-token/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing WETH (62/100)
# Error getting market cap for binance-peg-weth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/binance-peg-weth/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing RUNE (63/100)
# Error getting market cap for thorchain: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing SEI (64/100)
# Error getting market cap for sei-network: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/sei-network/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing GRT (65/100)
# Error getting market cap for the-graph: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/the-graph/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing RETH (66/100)
# Error getting market cap for rocket-pool-eth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/rocket-pool-eth/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing POPCAT (67/100)
# Error getting market cap for popcat: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/popcat/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing ENA (68/100)
# Error getting market cap for ethena: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethena/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing PNUT (69/100)
# Error getting market cap for peanut-the-squirrel: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/peanut-the-squirrel/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing JUP (70/100)
# Error getting market cap for jupiter-exchange-solana: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/jupiter-exchange-solana/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing METH (71/100)
# Error getting market cap for mantle-staked-ether: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mantle-staked-ether/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing PYTH (72/100)
# Error getting market cap for pyth-network: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/pyth-network/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing WLD (73/100)
# Error getting market cap for worldcoin-wld: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/worldcoin-wld/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing EZETH (74/100)
# Error getting market cap for renzo-restaked-eth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/renzo-restaked-eth/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing SOLVBTC (75/100)
# Error getting market cap for solv-btc: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solv-btc/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing THETA (76/100)
# Error getting market cap for theta-token: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/theta-token/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing CBBTC (77/100)
# Error getting market cap for coinbase-wrapped-btc: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/coinbase-wrapped-btc/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing MKR (78/100)
# Error getting market cap for maker: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/maker/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing KCS (79/100)
# Error getting market cap for kucoin-shares: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/kucoin-shares/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing BRETT (80/100)
# Error getting market cap for based-brett: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/based-brett/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing RAY (81/100)
# Error getting market cap for raydium: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/raydium/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing ONDO (82/100)
# Error getting market cap for ondo-finance: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ondo-finance/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing BSV (83/100)
# Error getting market cap for bitcoin-cash-sv: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bitcoin-cash-sv/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing OM (84/100)
# Error getting market cap for mantra-dao: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mantra-dao/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing ALGO (85/100)
# Error getting market cap for algorand: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/algorand/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing GT (86/100)
# Error getting market cap for gatechain-token: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/gatechain-token/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing AR (87/100)
# Error getting market cap for arweave: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing MSOL (88/100)
# Error getting market cap for msol: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/msol/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing BEAM (89/100)
# Error getting market cap for beam-2: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/beam-2/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing GALA (90/100)
# Error getting market cap for gala: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/gala/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing EETH (91/100)
# Error getting market cap for ether-fi-staked-eth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ether-fi-staked-eth/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing LDO (92/100)
# Error getting market cap for lido-dao: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/lido-dao/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing NEIRO (93/100)
# Error getting market cap for neiro-3: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/neiro-3/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing FTN (94/100)
# Error getting market cap for fasttoken: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/fasttoken/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing BTT (95/100)
# Error getting market cap for bittorrent: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/bittorrent/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing HNT (96/100)
# Error getting market cap for helium: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/helium/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing STRK (97/100)
# Error getting market cap for starknet: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/starknet/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing LBTC (98/100)
# Error getting market cap for lombard-staked-btc: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/lombard-staked-btc/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing JASMY (99/100)
# Error getting market cap for jasmycoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/jasmycoin/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
# Processing MATIC (100/100)
# Error getting market cap for matic-network: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/market_chart/range?vs_currency=usd&from=1514777400&to=1731468600
#
# Processing list: 2020-01-01_t100
# Processing BTC (1/100)
# Error getting market cap for bitcoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing ETH (2/100)
# Error getting market cap for ethereum: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing USDT (3/100)
# Error getting market cap for tether: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tether/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing SOL (4/100)
# Error getting market cap for solana: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing BNB (5/100)
# Error getting market cap for binancecoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/binancecoin/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing DOGE (6/100)
# Error getting market cap for dogecoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/dogecoin/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing XRP (7/100)
# Error getting market cap for ripple: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ripple/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing USDC (8/100)
# Error getting market cap for usd-coin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/usd-coin/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing STETH (9/100)
# Error getting market cap for staked-ether: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/staked-ether/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing ADA (10/100)
# Error getting market cap for cardano: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing SHIB (11/100)
# Error getting market cap for shiba-inu: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/shiba-inu/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing TRX (12/100)
# Error getting market cap for tron: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tron/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing WSTETH (13/100)
# Error getting market cap for wrapped-steth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/wrapped-steth/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing AVAX (14/100)
# Error getting market cap for avalanche-2: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/avalanche-2/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing TON (15/100)
# Error getting market cap for the-open-network: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/the-open-network/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing WBTC (16/100)
# Error getting market cap for wrapped-bitcoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/wrapped-bitcoin/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing SUI (17/100)
# Error getting market cap for sui: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/sui/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing WETH (18/100)
# Error getting market cap for weth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/weth/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing PEPE (19/100)
# Error getting market cap for pepe: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/pepe/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing BCH (20/100)
# Error getting market cap for bitcoin-cash: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bitcoin-cash/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing LINK (21/100)
# Error getting market cap for chainlink: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/chainlink/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing DOT (22/100)
# Error getting market cap for polkadot: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/polkadot/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing LEO (23/100)
# Error getting market cap for leo-token: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/leo-token/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing NEAR (24/100)
# Error getting market cap for near: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/near/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing APT (25/100)
# Error getting market cap for aptos: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/aptos/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing WEETH (26/100)
# Error getting market cap for wrapped-eeth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/wrapped-eeth/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing LTC (27/100)
# Error getting market cap for litecoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/litecoin/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing UNI (28/100)
# Error getting market cap for uniswap: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/uniswap/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing USDS (29/100)
# Error getting market cap for usds: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/usds/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing CRO (30/100)
# Error getting market cap for crypto-com-chain: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/crypto-com-chain/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing ICP (31/100)
# Error getting market cap for internet-computer: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/internet-computer/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing TAO (32/100)
# Error getting market cap for bittensor: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bittensor/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing WIF (33/100)
# Error getting market cap for dogwifcoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/dogwifcoin/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing XLM (34/100)
# Error getting market cap for stellar: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/stellar/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing ETC (35/100)
# Error getting market cap for ethereum-classic: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum-classic/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing FET (36/100)
# Error getting market cap for fetch-ai: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fetch-ai/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing KAS (37/100)
# Error getting market cap for kaspa: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/kaspa/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing DAI (38/100)
# Error getting market cap for dai: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/dai/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing WBT (39/100)
# Error getting market cap for whitebit: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/whitebit/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing POL (40/100)
# Error getting market cap for polygon-ecosystem-token: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/polygon-ecosystem-token/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing USDE (41/100)
# Error getting market cap for ethena-usde: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/ethena-usde/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing STX (42/100)
# Error getting market cap for blockstack: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/blockstack/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing BONK (43/100)
# Error getting market cap for bonk: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/bonk/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing RENDER (44/100)
# Error getting market cap for render-token: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/render-token/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing XMR (45/100)
# Error getting market cap for monero: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/monero/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing OKB (46/100)
# Error getting market cap for okb: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/okb/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing AAVE (47/100)
# Error getting market cap for aave: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/aave/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing ARB (48/100)
# Error getting market cap for arbitrum: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arbitrum/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing FIL (49/100)
# Error getting market cap for filecoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/filecoin/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing MNT (50/100)
# Error getting market cap for mantle: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mantle/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing INJ (51/100)
# Error getting market cap for injective-protocol: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/injective-protocol/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing FLOKI (52/100)
# Error getting market cap for floki: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/floki/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing FDUSD (53/100)
# Error getting market cap for first-digital-usd: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/first-digital-usd/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing HBAR (54/100)
# Error getting market cap for hedera-hashgraph: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/hedera-hashgraph/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing VET (55/100)
# Error getting market cap for vechain: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/vechain/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing TIA (56/100)
# Error getting market cap for celestia: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/celestia/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing IMX (57/100)
# Error getting market cap for immutable-x: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/immutable-x/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing OP (58/100)
# Error getting market cap for optimism: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/optimism/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing FTM (59/100)
# Error getting market cap for fantom: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing ATOM (60/100)
# Error getting market cap for cosmos: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cosmos/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing BGB (61/100)
# Error getting market cap for bitget-token: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bitget-token/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing WETH (62/100)
# Error getting market cap for binance-peg-weth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/binance-peg-weth/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing RUNE (63/100)
# Error getting market cap for thorchain: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing SEI (64/100)
# Error getting market cap for sei-network: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/sei-network/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing GRT (65/100)
# Error getting market cap for the-graph: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/the-graph/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing RETH (66/100)
# Error getting market cap for rocket-pool-eth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/rocket-pool-eth/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing POPCAT (67/100)
# Error getting market cap for popcat: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/popcat/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing ENA (68/100)
# Error getting market cap for ethena: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethena/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing PNUT (69/100)
# Error getting market cap for peanut-the-squirrel: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/peanut-the-squirrel/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing JUP (70/100)
# Error getting market cap for jupiter-exchange-solana: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/jupiter-exchange-solana/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing METH (71/100)
# Error getting market cap for mantle-staked-ether: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mantle-staked-ether/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing PYTH (72/100)
# Error getting market cap for pyth-network: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/pyth-network/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing WLD (73/100)
# Error getting market cap for worldcoin-wld: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/worldcoin-wld/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing EZETH (74/100)
# Error getting market cap for renzo-restaked-eth: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/renzo-restaked-eth/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing SOLVBTC (75/100)
# Error getting market cap for solv-btc: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solv-btc/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing THETA (76/100)
# Error getting market cap for theta-token: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/theta-token/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing CBBTC (77/100)
# Error getting market cap for coinbase-wrapped-btc: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/coinbase-wrapped-btc/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing MKR (78/100)
# Error getting market cap for maker: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/maker/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing KCS (79/100)
# Error getting market cap for kucoin-shares: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/kucoin-shares/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing BRETT (80/100)
# Error getting market cap for based-brett: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/based-brett/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing RAY (81/100)
# Error getting market cap for raydium: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/raydium/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing ONDO (82/100)
# Error getting market cap for ondo-finance: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ondo-finance/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing BSV (83/100)
# Error getting market cap for bitcoin-cash-sv: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bitcoin-cash-sv/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing OM (84/100)
# Error getting market cap for mantra-dao: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mantra-dao/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing ALGO (85/100)
# Error getting market cap for algorand: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/algorand/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing GT (86/100)
# Error getting market cap for gatechain-token: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/gatechain-token/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing AR (87/100)
# Error getting market cap for arweave: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing MSOL (88/100)
# Error getting market cap for msol: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/msol/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing BEAM (89/100)
# Error getting market cap for beam-2: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/beam-2/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing GALA (90/100)
# Error getting market cap for gala: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/gala/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing EETH (91/100)
# Error getting market cap for ether-fi-staked-eth: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/ether-fi-staked-eth/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing LDO (92/100)
# Error getting market cap for lido-dao: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/lido-dao/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing NEIRO (93/100)
# Error getting market cap for neiro-3: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/neiro-3/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing FTN (94/100)
# Error getting market cap for fasttoken: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fasttoken/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing BTT (95/100)
# Error getting market cap for bittorrent: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bittorrent/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing HNT (96/100)
# Error getting market cap for helium: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/helium/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing STRK (97/100)
# Error getting market cap for starknet: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/starknet/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing LBTC (98/100)
# Error getting market cap for lombard-staked-btc: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/lombard-staked-btc/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing JASMY (99/100)
# Error getting market cap for jasmycoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/jasmycoin/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
# Processing MATIC (100/100)
# Error getting market cap for matic-network: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/market_chart/range?vs_currency=usd&from=1577849400&to=1731468600
#
# Processing list: 2022-01-01_t100
# Processing BTC (1/100)
# Error getting market cap for bitcoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1641007800&to=1731468600
# Processing ETH (2/100)
# Error getting market cap for ethereum: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/market_chart/range?vs_currency=usd&from=1641007800&to=1731468600
# Processing USDT (3/100)
# Error getting market cap for tether: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tether/market_chart/range?vs_currency=usd&from=1641007800&to=1731468600
# Processing SOL (4/100)
# Error getting market cap for solana: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/market_chart/range?vs_currency=usd&from=1641007800&to=1731468600
# Processing BNB (5/100)
# Error getting market cap for binancecoin: 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/binancecoin/market_chart/range?vs_currency=usd&from=1641007800&to=1731468600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 175
#     172         print(f"Min Market Cap: ${df_subset['total_market_cap'].min()/1e9:.2f}B")
#     174 if __name__ == "__main__":
# --> 175     main()
#
# Cell In[2], line 141, in main()
#     139 # Track market caps with progress updates
#     140 print("\nTracking market caps...")
# --> 141 market_cap_data = track_market_caps(historical_lists)
#     143 # Convert to DataFrame
#     144 market_cap_records = []
#
# Cell In[2], line 76, in track_market_caps(historical_lists)
#      73                 date = datetime.fromtimestamp(timestamp_ms/1000).strftime('%Y-%m-%d')
#      74                 daily_totals[date] = daily_totals.get(date, 0) + market_cap
# ---> 76         time.sleep(1.2)  # Respect rate limits
#      78     all_market_caps[date_label] = daily_totals
#      80 return all_market_caps
#
# KeyboardInterrupt:
